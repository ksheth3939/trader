# %%
import pandas as pd
import numpy as np
import yfinance as yf

# %%
trades = pd.read_csv('trades.csv')
trades
# Out:
#                          Datetime Ticker Action  ShareAmount  Value  \
# 0      2021-09-09 10:25:04.301858   AKAM    BUY     0.441200   50.0
# 1      2021-09-17 15:25:03.599945   AMCR    BUY    24.347516    0.0
# 2      2021-09-17 15:25:03.891239    AEP    BUY    14.123380    0.0
# 3      2021-09-20 11:47:18.990240    ACN    BUY    22.059733    0.0
# 4      2021-09-20 11:47:19.613108    AFL    BUY    15.457371    0.0
# ...                           ...    ...    ...          ...    ...
# 1326   2021-11-02 12:25:36.321335    MTD    BUY    52.574460    0.0
# 1327   2021-11-02 13:25:16.812266   CTXS    BUY    51.182925    0.0
# 1328   2021-11-02 13:25:24.438362   FITB   SELL    43.229685    0.0
# 1329   2021-11-02 13:25:33.747628    LOW    BUY    55.620514    0.0
# 1330   2021-11-02 14:25:11.899944    AVB    BUY    54.113132    0.0
#
#       YFSharePrice AlgoType
# 0       113.290001    Stoch
# 1        11.845000      RSI
# 2        84.654999      RSI
# 3       331.829987      RSI
# 4        52.029999      RSI
# ...            ...      ...
# 1326   1467.260010    Stoch
# 1327     95.269997    Stoch
# 1328     43.840000    Stoch
# 1329    233.490005    Stoch
# 1330    236.375000    Stoch
#
# [1331 rows x 7 columns]

# %%
stoch = trades[trades['AlgoType'] == 'Stoch']
rsi = trades[trades['AlgoType'] == 'RSI']

rsi_buy = rsi[rsi['Action'] == 'BUY']
rsi_sell = rsi[rsi['Action'] == 'SELL']
stoch_buy = stoch[stoch['Action'] == 'BUY']
stoch_sell = stoch[stoch['Action'] == 'SELL']

stoch_stocks_sold = set(stoch_sell['Ticker'])
rsi_stocks_sold = set(rsi_sell['Ticker'])

print('stoch sold' , len(stoch_stocks_sold))
print('RSI sold' , len(rsi_stocks_sold))
stoch_sell
# Out:
# stoch sold 267
# RSI sold 103
#                         Datetime Ticker Action  ShareAmount      Value  \
# 255   2021-09-23 10:25:23.197153   EQIX   SELL     0.058100  49.649064
# 261   2021-09-23 11:25:26.303437    HCA   SELL     0.193100  49.641185
# 267   2021-09-23 14:26:19.501447    CAG   SELL     1.503800  49.971273
# 268   2021-09-23 15:25:37.083737    LOW   SELL     0.241400  50.302933
# 269   2021-09-24 12:25:06.334275   ABBV   SELL     0.466700  49.801557
# ...                          ...    ...    ...          ...        ...
# 1317  2021-11-02 11:25:13.558419   BIIB   SELL    48.191504   0.000000
# 1318  2021-11-02 11:25:15.617478   CTLT   SELL    45.407420   0.000000
# 1321  2021-11-02 11:25:37.238530    MGM   SELL    46.861354   0.000000
# 1324  2021-11-02 12:25:13.263747   BKNG   SELL    47.284231   0.000000
# 1328  2021-11-02 13:25:24.438362   FITB   SELL    43.229685   0.000000
#
#       YFSharePrice AlgoType
# 255     854.544983    Stoch
# 261     257.075012    Stoch
# 267      33.230000    Stoch
# 268     208.380005    Stoch
# 269     106.709999    Stoch
# ...            ...      ...
# 1317    267.309998    Stoch
# 1318    135.945007    Stoch
# 1321     47.380001    Stoch
# 1324   2435.739990    Stoch
# 1328     43.840000    Stoch
#
# [323 rows x 7 columns]

# %%
count = stoch.groupby(by = ['Ticker']).count().sort_values(by = ['Datetime'])
count = count[count['Datetime'] % 2 == 0]
count
print('Stoch', sum(count.Datetime))
bought_sold_stoch = set(count.index).intersection(stoch_stocks_sold)
len(bought_sold_stoch)
stoch_pairs = stoch[stoch.Ticker.isin(bought_sold_stoch)]

count = rsi.groupby(by = ['Ticker']).count().sort_values(by = ['Datetime'])
count = count[count['Datetime'] % 2 == 0]
count
print('RSI', sum(count.Datetime))
bought_sold_rsi = set(count.index).intersection(rsi_stocks_sold)
len(bought_sold_rsi)
rsi_pairs = rsi[rsi.Ticker.isin(bought_sold_rsi)]
rsi_pairs
# Out:
# Stoch 448
# RSI 258
#                         Datetime Ticker Action  ShareAmount      Value  \
# 3     2021-09-20 11:47:18.990240    ACN    BUY    22.059733   0.000000
# 4     2021-09-20 11:47:19.613108    AFL    BUY    15.457371   0.000000
# 5     2021-09-20 11:47:19.807296    APD    BUY    19.975810   0.000000
# 7     2021-09-20 11:47:20.933608   AMZN    BUY    24.805908   0.000000
# 10    2021-09-20 11:47:21.824131    AMP    BUY    20.429516   0.000000
# ...                          ...    ...    ...          ...        ...
# 1239  2021-10-28 15:25:48.391137    NOC    BUY     0.141100  49.988202
# 1241  2021-10-29 10:25:06.762023    AFL    BUY     0.924600  50.002370
# 1272  2021-10-29 14:25:15.485276     CE    BUY     0.311400  49.998383
# 1300  2021-11-01 15:25:15.952584    CCL   SELL     2.232000  51.369479
# 1319  2021-11-02 11:25:18.244274    CLX   SELL     0.317600  53.105355
#
#       YFSharePrice AlgoType
# 3       331.829987      RSI
# 4        52.029999      RSI
# 5       257.148987      RSI
# 7      3357.419922      RSI
# 10      256.184998      RSI
# ...            ...      ...
# 1239    354.274994      RSI
# 1241     54.080002      RSI
# 1272    160.559998      RSI
# 1300     23.014999      RSI
# 1319    167.208298      RSI
#
# [180 rows x 7 columns]

# %%
stoch_percents = []
for comp in bought_sold_stoch:
    x = stoch_pairs[stoch_pairs['Ticker'] == comp]
    x = x.groupby(by = ['Action']).sum()
    stoch_percents.append((x['Value'][1] - x['Value'][0]) / x['Value'][0])
print('Stoch' ,np.mean(stoch_percents), np.std(stoch_percents), len(stoch_percents))

rsi_percents = []
for comp in bought_sold_rsi:
    x = rsi_pairs[rsi_pairs['Ticker'] == comp]
    x = x.groupby(by = ['Action']).sum()
#     print('asdf', (x['YFSharePrice'][1] - x['YFSharePrice'][0]) / x['YFSharePrice'][0])
    rsi_percents.append((x['YFSharePrice'][1] - x['YFSharePrice'][0]) / x['YFSharePrice'][0])
print('RSI' , np.mean(rsi_percents), np.std(rsi_percents), len(rsi_percents), min(rsi_percents), max(rsi_percents))
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in double_scalars
#   """
# Stoch nan nan 181
# RSI 0.14547432114473527 0.5713437986215574 80 -0.6561055659401145 4.106681301763339

# %%
yf.download(tickers = 'SPY', start = '2021-09-20', interval = '1h').reset_index()

# %%
count = stoch.groupby(by = ['Ticker']).count().sort_values(by = ['Datetime'])
count = count[count['Datetime'] % 2 == 0]
count
print('Stoch', sum(count.Datetime))
bought_sold_stoch = set(count.index).intersection(stoch_stocks_sold)
len(bought_sold_stoch)
stoch_pairs = stoch[stoch.Ticker.isin(bought_sold_stoch)]

# %%
rsi_sells.groupby(by = ['Ticker', 'Action']).count()

# %%
rsi_sells[rsi_sells['Ticker'] == 'AMP']
